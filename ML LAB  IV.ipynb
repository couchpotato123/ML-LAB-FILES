# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df= pd.read_excel("AirQualityUCI.xlsx")
df                                                   #there are null values in this
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %%
df.isna().sum()
# Out:
# Date                0
# Time                0
# CO(GT)              0
# PT08.S1(CO)         0
# NMHC(GT)            0
# C6H6(GT)            0
# PT08.S2(NMHC)       0
# NOx(GT)             0
# PT08.S3(NOx)        0
# NO2(GT)             0
# PT08.S4(NO2)        0
# PT08.S5(O3)         0
# T                   0
# RH                  0
# AH                  0
# Unnamed: 15      9357
# Unnamed: 16      9357
# dtype: int64

# %%
df2=df.drop(['Unnamed: 15', 'Unnamed: 16'], axis = 1)
df2
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %%
#here the dependent variable is RH and all the other previous columns are independent variables

# %%
df2.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
print(x_train, x_test, y_train, y_test)
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 3461     1.7      1169.75      -200   9.514487         959.25     86.0
# 4160  -200.0       869.25      -200   2.936204         648.00   -200.0
# 1336     2.9      1172.25      -200  13.024928        1084.50    214.0
# 8587     1.4      1092.25      -200   4.902415         758.50    267.9
# 560      1.2      1140.75        88   5.277768         777.25     69.0
# ...      ...          ...       ...        ...            ...      ...
# 9241     4.2      1359.75      -200  19.940394        1294.75    474.7
# 6568     1.4       936.75      -200   4.736157         750.00    263.0
# 2702     3.9      1379.50      -200  22.308583        1359.25    239.0
# 8030     2.1      1222.75      -200  10.043405         979.25    455.2
# 9080     0.9      1044.25      -200   3.843684         702.00    164.8
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)
# 3461        666.25     88.0       1797.50       837.75
# ...

# %%
#x = df[['CO(GT)', 'PT08.S1(CO)','NMHC(GT)', 'C6H6(GT)','PT08.S2(NMHC)', 'NOx(GT)','PT08.S3(NOx)', 'NO2(GT)','PT08.S4(NO2)','PT08.S5(O3)']]
#y = df['RH']

# %%
regr = LinearRegression()
regr.fit(x, y)
# Out:
# LinearRegression()

# %%
pred = regr.predict([['2.6','1360','150','11.9','1046','166','1056','113','1692','1268',]])
pred
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# array([48.35047125])

# %%
ax1 =df.plot(kind='scatter', x=['CO(GT)','PT08.S1(CO)'], y=['RH','RH'], color=['blue'], alpha=0.5, figsize=(10, 7))
df.plot(kind='scatter', x='PT08.S1(CO)', y='RH', color='purple', alpha=0.5, figsize=(10, 7),ax=ax1)
df.plot(kind='scatter', x='C6H6(GT)', y='RH', color='yellow', alpha=0.5, figsize=(10, 7),ax=ax1)
df.plot(kind='scatter', x='PT08.S2(NMHC)', y='RH', color='brown', alpha=0.5, figsize=(10, 7),ax=ax1)
df.plot(kind='scatter', x='NOx(GT)', y='RH', color='red', alpha=0.5, figsize=(10, 7),ax=ax1)
df.plot(kind='scatter', x='PT08.S3(NOx)', y='RH', color='green', alpha=0.5, figsize=(10, 7),ax=ax1)
df.plot(kind='scatter', x='NO2(GT)', y='RH', color='orange', alpha=0.5, figsize=(10, 7),ax=ax1)
df.plot(kind='scatter', x='PT08.S4(NO2)', y='RH', color='pink', alpha=0.5, figsize=(10, 7),ax=ax1)
# Out:
# <AxesSubplot:xlabel='PT08.S4(NO2)', ylabel='RH'>
