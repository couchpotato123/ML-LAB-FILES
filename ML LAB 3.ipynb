# %% [markdown]
# PRE LAB

# %%
#Entropy
'''The measure of disorder in given dataset is called Entropy'''
#Information Gain
'''The measure of reduction of entropy in a data set is called Indformation Gain'''
#Gini Index
'''It is the degree of probability of a particular varibale that it will be wrongly classified when it is chosen
                                                                                    randomly'''

#Gain Ratio
'''it is the ratio between information gain and entropy which is often used as an uncertainity coeffecient'''
# Out:
# 'it is the ratio between information gain and entropy which is often used as an uncertainity coeffecient'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

A=pd.read_csv("tennis.csv")
A
# Out:
#      outlook  temp humidity    wind play
# 0      Sunny   Hot     High    Weak   No
# 1      Sunny   Hot     High  Strong   No
# 2   Overcast   Hot     High    Weak  Yes
# 3       Rain  Mild     High    Weak  Yes
# 4       Rain  Cool   Normal    Weak  Yes
# 5       Rain  Cool   Normal  Strong   No
# 6   Overcast  Cool   Normal  Strong  Yes
# 7      Sunny  Mild     High    Weak   No
# 8      Sunny  Cool   Normal    Weak  Yes
# 9       Rain  Mild   Normal    Weak  Yes
# 10     Sunny  Mild   Normal  Strong  Yes
# 11  Overcast  Mild     High  Strong  Yes
# 12  Overcast   Hot   Normal    Weak  Yes
# 13      Rain  Mild     High  Strong   No

# %%
from sklearn.preprocessing import LabelEncoder 

X=A.apply(LabelEncoder().fit_transform)
X
# Out:
#     outlook  temp  humidity  wind  play
# 0         2     1         0     1     0
# 1         2     1         0     0     0
# 2         0     1         0     1     1
# 3         1     2         0     1     1
# 4         1     0         1     1     1
# 5         1     0         1     0     0
# 6         0     0         1     0     1
# 7         2     2         0     1     0
# 8         2     0         1     1     1
# 9         1     2         1     1     1
# 10        2     2         1     0     1
# 11        0     2         0     0     1
# 12        0     1         1     1     1
# 13        1     2         0     0     0

# %%
N = X.drop(columns=['play'], axis=1)
T=X['play']
x_train,x_test,y_train,y_test = train_test_split(N,T)



model = DecisionTreeClassifier(criterion = "entropy")
model.fit(x_train, y_train)
train_score = model.score(x_train, y_train)
test_score = model.score(x_test, y_test)
print(train_score)
print(test_score)
# Out:
# 1.0
# 0.25

# %%
model = DecisionTreeClassifier(criterion = "gini")
model.fit(x_train, y_train)
train_score = model.score(x_train, y_train)
test_score = model.score(x_test, y_test)
print(train_score)
print(test_score)
# Out:
# 1.0
# 0.25
